# %%
print("Hello Jupyter!")
# Out:
# Hello Jupyter!

# %% [markdown]
# User single _underscores_ or single *asterisks* to get italics

# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3

# %% [markdown]
# * item 1
#     * sub-item 1

# %% [markdown]
# ```python
# s = "Syntax highlighting for Python"
# print(s)
# ````

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# ![sprint2Nivell1Exercici3.jpg](attachment:sprint2Nivell1Exercici3.jpg)

# %%
15+8*3
# Out:
# 39

# %%
print(5/8)
print(7+10)
# Out:
# 0.625
# 17

# %%
#Nivel - Exercici 2
print(5/8)
print(7+10)
# Out:
# 0.625
# 17

# %%
5/8
# Out:
# 0.625

# %%
tshirts = {'red': 1, 'white': 5, "blue": 2, 'black': 3}
