# %% [markdown]
# # Header 1
# ## Header 2
# ### Header 3
# #### Header 4
# ##### Header 5

# %% [markdown]
# * Main Item 1
#     * Subitem 1.1
#     * Subitem 1.2
#     * Subitem 1.3
# * Main Item 2
# * Main Item 3

# %% [markdown]
# + Exercise 1
# + Exercise 2
# - Exercise 3

# %% [markdown]
# 1. Item 1
# 2. Item 2
#          2.1 Subitem 2a
#          2.2 Subitem 2b
# 3. Item 3
#          3.1 Subitem 3a

# %% [markdown]
# Use single _underscores_ or single *asterisks* to get italics

# %% [markdown]
# *italics*

# %% [markdown]
# *italics**bold and italics**italics*

# %% [markdown]
# **bold**

# %% [markdown]
# ![sprint2Nivell1Exercici3a.jpg](attachment:sprint2Nivell1Exercici3a.jpg)
